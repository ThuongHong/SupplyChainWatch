# %% [markdown]
# # 05 Initial EDA
#
# Goal: summarize distribution, missingness, and outliers after the first pipeline run.
#
# Checklist:
# - Row counts by source.
# - Missing values by column.
# - Vessel speed distribution.
# - Freight index daily changes.
# - Collection failures from `collection_log`.

# %%
import pandas as pd

# Fill in after migrations and collectors are running.
