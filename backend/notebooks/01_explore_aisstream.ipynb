# %% [markdown]
# # 01 Explore AISStream
#
# Goal: verify credentials, inspect vessel snapshot fields, and save a small anonymized sample for parser tests.

# %%
import os
import httpx

api_key = os.getenv('AISSTREAM_API_KEY')
assert api_key, 'Set AISSTREAM_API_KEY before running live exploration'
