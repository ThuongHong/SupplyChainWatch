# %% [markdown]
# # 03 Explore UN Comtrade
#
# Goal: test one monthly trade query and document field mappings for `trade_flows`.

# %%
import os

api_key = os.getenv('UN_COMTRADE_API_KEY')
assert api_key, 'Set UN_COMTRADE_API_KEY before running live exploration'
