# %% [markdown]
# # 02 Explore FRED
#
# Goal: list candidate freight and fuel proxy series, confirm observation cadence, and identify missing-value behavior.

# %%
import os
import httpx

api_key = os.getenv('FRED_API_KEY')
assert api_key, 'Set FRED_API_KEY before running live exploration'
