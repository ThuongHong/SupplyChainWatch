# %% [markdown]
# # 04 Explore Open-Meteo Marine
#
# Goal: verify route-point weather calls and inspect hourly marine variables.

# %%
import httpx

url = 'https://marine-api.open-meteo.com/v1/marine'
params = {'latitude': 29.97, 'longitude': 32.55, 'hourly': 'wave_height', 'timezone': 'UTC', 'forecast_days': 1}
# response = httpx.get(url, params=params, timeout=30)
# response.json()
